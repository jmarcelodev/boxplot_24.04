# %%
#Importar bibliotecas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Carregar a planilha .csv que deesja
df1 = pd.read_csv('605_2_valid.csv')

# %%
#Criar objeto com a produtividade e produtividade predita
produtividade = df1['produtivid']
produtividade_predita = df1['Prod_pred']

# %%
#Plot do gráfico
plt.figure(figsize=(10, 6)) #Tamanho da figura
plt.boxplot([produtividade, produtividade_predita], labels=['Produtividade', 'Produtividade Predita']) #Obejtos presentes
plt.title(' Produtividade e Produtividade Predita') #Título
plt.ylabel('Valores'+' (t/ha)') #Descrição do eixo Y
plt.xlabel('Talhão 605_2') #Descrição do eixo X
plt.grid(True) # Ter o grid
plt.show()

# %%
df2 = pd.read_csv('605_7_valid.csv')

# %%
produtividade2 = df2['produtivid']
produtividade_predita2 = df2['Prod_pred']

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([produtividade2, produtividade_predita2], labels=['Produtividade', 'Produtividade Predita'])
plt.title(' Produtividade e Produtividade Predita')
plt.ylabel('Valores'+' (t/ha)')
plt.xlabel('Talhão 605_7')
plt.grid(True)
plt.show()

# %%
df3 = pd.read_csv('606_6_valid.csv')

# %%
produtividade3 = df3['produtivid']
produtividade_predita3 = df3['Prod_pred']

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([produtividade3, produtividade_predita3], labels=['Produtividade', 'Produtividade Predita'])
plt.title(' Produtividade e Produtividade Predita')
plt.ylabel('Valores'+' (t/ha)')
plt.xlabel('Talhão 606_6')
plt.grid(True)
plt.show()

# %%
df4 = pd.read_csv('607_3_valid.csv')
produtividade4 = df4['produtivid']
produtividade_predita4 = df4['Prod_pred']
plt.figure(figsize=(10, 6))
plt.boxplot([produtividade4, produtividade_predita4], labels=['Produtividade', 'Produtividade Predita'])
plt.title(' Produtividade e Produtividade Predita')
plt.ylabel('Valores'+' (t/ha)')
plt.xlabel('Talhão 607_3')
plt.grid(True)
plt.show()
